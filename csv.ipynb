# %%
import csv
with open('test.csv','a',encoding="utf-8") as newFile:
    newFileWriter = csv.writer(newFile)
    newFileWriter.writerow(['category','news'])
    for i in range(1,5):
        data_path = 'Document_Categorization/category/accident/link'+str(i)+'.txt'
        print(data_path)
        with open(data_path, 'r', encoding='utf-8') as f:
            line = f.read().split('\n')
            print(line)
            newFileWriter.writerow(['accident',line])
# Out:
# Document_Categorization/category/accident/link1.txt
# ['নওগাঁর মহাদেবপুর উপজেলার নওগাঁ-রাজশাহী মহাসড়কে আজ শুক্রবার রাতে বরযাত্রীবাহী একটি বাস ও ট্রাকের সংঘর্ষের ঘটনা ঘটেছে। এতে চার জন নিহত ও অন্তত ২০ জন আহত হয়েছেন। রাত পৌনে নয়টার দিকে উপজেলার নওহাটা মোড়ে এ ঘটনা ঘটে। পুলিশ ও ফায়ার সার্ভিসের কর্মীরা ঘটনাস্থলে উদ্ধার অভিযান শুরু করেছে। রাত সোয়া ১১টায় শেষ খবর পাওয়া পর্যন্ত ওই লাশ চারটি বাসের ভেতর থেকে উদ্ধার করা সম্ভব হয়নি। পুলিশ জানায়, নওগাঁ থেকে বরযাত্রীবাহী বাসটি রাজশাহীর দিকে যাচ্ছিল। এ সময় নওহাটা মোড়ে বিপরীত দিক থেকে আসা একটি ট্রাকের সঙ্গে বাসটির মুখোমুখি সংঘর্ষ হয়। এতে বাসটি রাস্তার পাশের খাদে উল্টে পড়ে গেলে এই হতাহতের ঘটনা ঘটে। মহাদেবপুর থানার উপপরিদর্শক (এসআই) ইকবাল পাশা জানান, বাসের নিচে চারটি লাশ আটকে আছে। তবে তাদের এখনও উদ্ধার করা সম্ভব হয়নি। আহতদের উদ্ধার করে বিভিন্ন হাসপাতালে পাঠানো হয়েছে।', '']
# Document_Categorization/category/accident/link2.txt
# ...

# %%
import csv
with open('test.csv','a',encoding="utf-8") as newFile:
    newFileWriter = csv.writer(newFile)
    #newFileWriter.writerow(['category','news'])
    for i in range(1,5):
        data_path = 'Document_Categorization/category/art/link'+str(i)+'.txt'
        print(data_path)
        with open(data_path, 'r', encoding='utf-8') as f:
            line = f.read().split('\n')
            print(line)
            newFileWriter.writerow(['art',line])
# Out:
# Document_Categorization/category/art/link1.txt
# ...

# %%
import csv
with open('test.csv','a',encoding="utf-8") as newFile:
    newFileWriter = csv.writer(newFile)
    #newFileWriter.writerow(['category','news'])
    for i in range(1,5):
        data_path = 'Document_Categorization/category/crime/link'+str(i)+'.txt'
        print(data_path)
        with open(data_path, 'r', encoding='utf-8') as f:
            line = f.read().split('\n')
            print(line)
            newFileWriter.writerow(['crime',line])
# Out:
# Document_Categorization/category/crime/link1.txt
# ...

# %%
import csv
with open('test.csv','a',encoding="utf-8") as newFile:
    newFileWriter = csv.writer(newFile)
    #newFileWriter.writerow(['category','news'])
    for i in range(1,5):
        data_path = 'Document_Categorization/category/economics/link'+str(i)+'.txt'
        print(data_path)
        with open(data_path, 'r', encoding='utf-8') as f:
            line = f.read().split('\n')
            print(line)
            newFileWriter.writerow(['economics',line])
# Out:
# Document_Categorization/category/economics/link1.txt
# ...

# %%
import csv
with open('test.csv','a',encoding="utf-8") as newFile:
    newFileWriter = csv.writer(newFile)
    #newFileWriter.writerow(['category','news'])
    for i in range(1,5):
        data_path = 'Document_Categorization/category/education/link'+str(i)+'.txt'
        print(data_path)
        with open(data_path, 'r', encoding='utf-8') as f:
            line = f.read().split('\n')
            print(line)
            newFileWriter.writerow(['education',line])
# Out:
# Document_Categorization/category/education/link1.txt
# ...

# %%
import csv
with open('test.csv','a',encoding="utf-8") as newFile:
    newFileWriter = csv.writer(newFile)
    #newFileWriter.writerow(['category','news'])
    for i in range(1,5):
        data_path = 'Document_Categorization/category/entertainment/link'+str(i)+'.txt'
        print(data_path)
        with open(data_path, 'r', encoding='utf-8') as f:
            line = f.read().split('\n')
            print(line)
            newFileWriter.writerow(['entertainment',line])
# Out:
# Document_Categorization/category/entertainment/link1.txt
# ...

# %%
import csv
with open('test.csv','a',encoding="utf-8") as newFile:
    newFileWriter = csv.writer(newFile)
    #newFileWriter.writerow(['category','news'])
    for i in range(1,5):
        data_path = 'Document_Categorization/category/environment/link'+str(i)+'.txt'
        print(data_path)
        with open(data_path, 'r', encoding='utf-8') as f:
            line = f.read().split('\n')
            print(line)
            newFileWriter.writerow(['environment',line])
# Out:
# Document_Categorization/category/environment/link1.txt
# ...

# %%
import csv
with open('test.csv','a',encoding="utf-8") as newFile:
    newFileWriter = csv.writer(newFile)
    #newFileWriter.writerow(['category','news'])
    for i in range(1,5):
        data_path = 'Document_Categorization/category/international/link'+str(i)+'.txt'
        print(data_path)
        with open(data_path, 'r', encoding='utf-8') as f:
            line = f.read().split('\n')
            print(line)
            newFileWriter.writerow(['international',line])
# Out:
# Document_Categorization/category/international/link1.txt
# ...

# %%
import csv
with open('test.csv','a',encoding="utf-8") as newFile:
    newFileWriter = csv.writer(newFile)
    #newFileWriter.writerow(['category','news'])
    for i in range(1,5):
        data_path = 'Document_Categorization/category/opinion/link'+str(i)+'.txt'
        print(data_path)
        with open(data_path, 'r', encoding='utf-8') as f:
            line = f.read().split('\n')
            print(line)
            newFileWriter.writerow(['opinion',line])
# Out:
# Document_Categorization/category/opinion/link1.txt
# ...

# %%
import csv
with open('test.csv','a',encoding="utf-8") as newFile:
    newFileWriter = csv.writer(newFile)
    #newFileWriter.writerow(['category','news'])
    for i in range(1,5):
        data_path = 'Document_Categorization/category/politics/link'+str(i)+'.txt'
        print(data_path)
        with open(data_path, 'r', encoding='utf-8') as f:
            line = f.read().split('\n')
            print(line)
            newFileWriter.writerow(['politics',line])
# Out:
# Document_Categorization/category/politics/link1.txt
# ...

# %%
import csv
with open('test.csv','a',encoding="utf-8") as newFile:
    newFileWriter = csv.writer(newFile)
    #newFileWriter.writerow(['category','news'])
    for i in range(1,5):
        data_path = 'Document_Categorization/category/science_tech/link'+str(i)+'.txt'
        print(data_path)
        with open(data_path, 'r', encoding='utf-8') as f:
            line = f.read().split('\n')
            print(line)
            newFileWriter.writerow(['science_tech',line])
# Out:
# Document_Categorization/category/science_tech/link1.txt
# ...

# %%
import csv
with open('test.csv','a',encoding="utf-8") as newFile:
    newFileWriter = csv.writer(newFile)
    #newFileWriter.writerow(['category','news'])
    for i in range(1,5):
        data_path = 'Document_Categorization/category/sports/link'+str(i)+'.txt'
        print(data_path)
        with open(data_path, 'r', encoding='utf-8') as f:
            line = f.read().split('\n')
            print(line)
            newFileWriter.writerow(['sports',line])
# Out:
# Document_Categorization/category/sports/link1.txt
# ...
